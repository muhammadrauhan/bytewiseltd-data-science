# %% [markdown]
# # Task 26: Classification Algorithm using Scikit-Learn:

# %% [markdown]
# Classification algorithms in scikit-learn are used to categorize data into predefined classes. Some common one includes,

# %% [markdown]
# - Logistic Regression.
# - K-Nearest Neighbors (K-NN).
# - Support Vector Machines (SVM).
# - Decision Trees.
# - Random Forests.
# - Gradient Boosting.
# - Naive Bayes.
